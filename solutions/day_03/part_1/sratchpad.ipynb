# %%
with open("input.txt") as f:
    data = f.read().splitlines()

# %%
# Out:
# number: 305, row: 0, start_index: 19, finish_index: 22
# None
# .....
# .-...
# True
#
# number: 124, row: 0, start_index: 23, finish_index: 26
# None
# .....
# ....&
# True
#
# number: 432, row: 0, start_index: 58, finish_index: 61
# None
# .....
# .....
# False
#
# number: 576, row: 0, start_index: 107, finish_index: 110
# None
# .....
# .....
# False
#
# number: 313, row: 0, start_index: 112, finish_index: 115
# None
# .....
# .....
# False
#
# number: 514, row: 0, start_index: 120, finish_index: 123
# None
# .....
# *....
# True
#
# number: 113, row: 1, start_index: 13, finish_index: 16
# .....
# .....
# ../..
# True
#
# number: 819, row: 1, start_index: 51, finish_index: 54
# .....
# .....
# .....
# False
#
# number: 654, row: 1, start_index: 65, finish_index: 68
# .....
# .....
# .....
# False
#
# number: 901, row: 1, start_index: 100, finish_index: 103
# .....
# &....
# .....
# True
#
# number: 869, row: 1, start_index: 124, finish_index: 127
# .....
# .....
# .*...
# True
#
# ...

# %%
# Out:
# 550891
